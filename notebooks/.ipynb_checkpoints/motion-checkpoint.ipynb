# %%
import os
os.chdir("..")

# %%
# %load_ext autoreload

# %%
# %autoreload 2
from src.transforms.base_transform import Preprocess, CreateSynthVolume
from src.dataset.ampscz.ampscz_dataset import PretrainValAMPSCZ
import matplotlib.pyplot as plt
import torchio as tio
from torchvision.transforms import ToPILImage
from monai.transforms.intensity.array import ScaleIntensity
from monai.losses.ssim_loss import SSIMMetric
from torchio import Subject
import seaborn as sb

# %%
unp = Preprocess()({"data":r"C:\Users\Brico\Code\Master\cinamon-cookie\data-test\MR-ART\sub-000148\anat\sub-000148_acq-standard_T1w.nii.gz"})
plt.imshow(unp['data'][0,120,:,:], cmap="gray")

# %%
ssim= SSIMMetric(3)

# %%
aug=tio.transforms.RandomMotion(degrees=1,translation=1, num_transforms=4)
vol, degree, translation = aug(unp["data"])
plt.imshow(vol[0,120,:,:], cmap="gray")
vol.max(), vol.min()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[56], line 2
#       1 aug=tio.transforms.RandomMotion(degrees=1,translation=1, num_transforms=4)
# ----> 2 vol, degree, translation = aug(unp["data"])
#       3 plt.imshow(vol[0,120,:,:], cmap="gray")
#       4 vol.max(), vol.min()
#
# File c:\Users\Brico\miniconda3\envs\bowl\lib\site-packages\torchio\transforms\transform.py:172, in Transform.__call__(self, data)
#     170 if self.parse_input:
#     171     self.add_transform_to_subject_history(transformed)
# --> 172     for image in transformed.get_images(intensity_only=False):
#     173         ndim = image.data.ndim
#     174         assert ndim == 4, f'Output of {self.name} is {ndim}D'
#
# AttributeError: 'tuple' object has no attribute 'get_images'

# %%
sub_unp = Subject(data=tio.ScalarImage(tensor=unp['data']))
sub_unp.plot()

# %%
aug=tio.transforms.RandomMotion(degrees=2,translation=5, num_transforms=4)
vol = aug(sub_unp)
vol.plot()

# %%
vol['data'].data
# Out:
# tensor([[[[-3.9339e-06, -1.8567e-05, -1.9312e-05,  ...,  1.8179e-05,
#            -1.7881e-07,  9.2983e-06],
#           [-7.3910e-06, -1.5348e-05, -1.6659e-05,  ...,  1.7285e-05,
#             6.9737e-06,  5.2452e-06],
#           [-9.0599e-06, -1.3083e-05, -2.1495e-05,  ...,  1.9133e-05,
#             1.1981e-05,  3.4571e-06],
#           ...,
#           [ 2.4358e-02,  1.6253e-02,  1.8426e-04,  ...,  7.0122e-03,
#            -4.9005e-02, -4.1399e-02],
#           [-2.2908e-02,  1.1994e-02,  1.8831e-04,  ..., -1.7826e-02,
#            -1.5869e-02,  1.8392e-02],
#           [ 1.1235e-02, -2.5245e-02,  7.7426e-03,  ...,  2.1199e-02,
#            -4.0658e-02,  2.0743e-02]],
#
#          [[-7.5400e-06, -1.9506e-05, -2.0370e-05,  ...,  1.8626e-05,
#             6.3479e-06,  9.1195e-06],
#           [-9.6858e-06, -1.7166e-05, -1.6823e-05,  ...,  1.7911e-05,
#             1.1623e-05,  3.0249e-06],
#           [-9.6112e-06, -1.4409e-05, -1.7345e-05,  ...,  1.4871e-05,
# ...

# %%
mot_transf = vol.get_composed_history()[0]
rot = mot_transf.degrees['data'][0]
transl = mot_transf.translation['data'][0]

rot, transl
# Out:
# (array([-1.4199283,  0.3282125,  1.3096974], dtype=float32),
#  array([-4.274028  , -0.06572151, -0.8549614 ], dtype=float32))

# %%
from scipy.spatial.transform import Rotation
import numpy as np
def get_affine(rot, transl):
    rot_mat = Rotation.from_rotvec(rot, True).as_matrix()
    affine_matrix = np.eye(4)
    affine_matrix[:3, :3] = rot_mat
    affine_matrix[:3, 3] = transl
    return affine_matrix

# %%
affine_t2 = get_affine(rot, transl)
affine_t1 = np.eye(4)

# %%
from fsl.transform.affine import rmsdev
rmsdev(affine_t1, affine_t2)
# Out:
# 4.237166783676317

# %%
from src.transforms.base_transform import get_affine, get_matrices, get_motion_dist

# %%
affines = get_matrices(mot_transf)
get_motion_dist(affines)
# Out:
# 6.109195399933818

# %%
convert  = ToPILImage(mode="L")
scale_01 = ScaleIntensity()
scaled = scale_01(vol)
converted = convert(scaled[0,120,:,:])
plt.imshow(converted, cmap="gray")

# %%
aug=CreateSynthVolume(elastic_activate=False)
vol =  aug(unp)
plt.imshow(vol["data"][0,120,:,:], cmap="gray")
vol['data'].max(), vol['data'].min(), vol['label'], vol['motion_mm'], vol['bin_centers']
# Out:
# (tensor(1186.3142),
#  tensor(-285.2930),
#  array([5.47467489e-08, 3.47617213e-07, 1.97510082e-06, 1.00420487e-05,
#         4.56878198e-05, 1.86004565e-04, 6.77628760e-04, 2.20904780e-03,
#         6.44411758e-03, 1.68215827e-02, 3.92930112e-02, 8.21313244e-02,
#         1.53619872e-01, 2.57117139e-01, 3.85087760e-01, 5.16099525e-01,
#         6.18945289e-01, 6.64226382e-01, 6.37859515e-01, 5.48124246e-01,
#         4.21481043e-01, 2.90016119e-01, 1.78571145e-01, 9.83887603e-02,
#         4.85092714e-02, 2.14017394e-02, 8.44925562e-03, 2.98492130e-03,
#         9.43609659e-04, 2.66929718e-04, 6.75688514e-05, 1.53052773e-05,
#         3.10227952e-06, 5.62685477e-07, 9.13262331e-08, 1.32638756e-08,
#         1.72381396e-09, 2.00472776e-10, 2.08624579e-11, 1.94276647e-12,
#         1.61890284e-13, 1.20716330e-14, 8.05482898e-16, 4.80940865e-17,
#         2.56963888e-18, 1.22856338e-19, 5.25615417e-21, 2.01225809e-22,
#         6.89357217e-24, 2.11324587e-25]),
#  3.5270910634602757,
# ...

# %%
from scipy.stats import norm

# %%
bins=np.linspace(0,10,51)
bins
# Out:
# array([ 0. ,  0.2,  0.4,  0.6,  0.8,  1. ,  1.2,  1.4,  1.6,  1.8,  2. ,
#         2.2,  2.4,  2.6,  2.8,  3. ,  3.2,  3.4,  3.6,  3.8,  4. ,  4.2,
#         4.4,  4.6,  4.8,  5. ,  5.2,  5.4,  5.6,  5.8,  6. ,  6.2,  6.4,
#         6.6,  6.8,  7. ,  7.2,  7.4,  7.6,  7.8,  8. ,  8.2,  8.4,  8.6,
#         8.8,  9. ,  9.2,  9.4,  9.6,  9.8, 10. ])

# %%
x=5.05
bin_centers = (bins[:-1] + bins[1:]) / 2
n=norm.pdf(bin_centers, loc=x, scale=0.6)
plt.bar( bin_centers, n,width=bin_centers[1] - bin_centers[0], align="center")
n
# Out:
# array([1.10452291e-15, 1.63439522e-14, 2.16413572e-13, 2.56422992e-12,
#        2.71878265e-11, 2.57950916e-10, 2.19000303e-09, 1.66378581e-08,
#        1.13108482e-07, 6.88078498e-07, 3.74563849e-06, 1.82456268e-05,
#        7.95310609e-05, 3.10212876e-04, 1.08274933e-03, 3.38174676e-03,
#        9.45146870e-03, 2.36375563e-02, 5.28994197e-02, 1.05936178e-01,
#        1.89837824e-01, 3.04415142e-01, 4.36812255e-01, 5.60878038e-01,
#        6.44446861e-01, 6.62599110e-01, 6.09620611e-01, 5.01895720e-01,
#        3.69753591e-01, 2.43756590e-01, 1.43795531e-01, 7.59065881e-02,
#        3.58557334e-02, 1.51559375e-02, 5.73260555e-03, 1.94028877e-03,
#        5.87659471e-04, 1.59268601e-04, 3.86259923e-05, 8.38251215e-06,
#        1.62784778e-06, 2.82877527e-07, 4.39873867e-08, 6.12072593e-09,
#        7.62118954e-10, 8.49156326e-11, 8.46637682e-12, 7.55357588e-13,
#        6.03049075e-14, 4.30821901e-15])

# %%
( vol['label']*vol['bin_centers']).sum()/vol['label'].sum()
# Out:
# 3.527091069900712

# %%
unp = Preprocess()([{"data":r"C:\Users\Brico\Code\Master\cinamon-cookie\data-test\MR-ART\sub-000148\anat\sub-000148_acq-standard_T1w.nii.gz"}])
