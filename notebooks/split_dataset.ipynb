# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
participant = pd.read_csv("participants.tsv", sep="\t")
participant.head()
# Out:
#   participant_id sex    age
# 0     sub-000103   M  24.45
# 1     sub-000148   F  25.01
# 2     sub-000149   F  44.32
# 3     sub-000159   F  27.34
# 4     sub-000175   M  32.60

# %%
scores = pd.read_csv("scores.tsv", sep="\t")
scores.head()
# Out:
#                         bids_name  score
# 0     sub-000103_acq-standard_T1w      1
# 1  sub-000103_acq-headmotion1_T1w      2
# 2  sub-000103_acq-headmotion2_T1w      3
# 3     sub-000148_acq-standard_T1w      1
# 4  sub-000148_acq-headmotion1_T1w      3

# %% [markdown]
# Here we perform a 60-20-20 split by **participant** to ensure no anatomical data leakage

# %%
X_train, X_test = train_test_split(
    participant["participant_id"], test_size=0.2, random_state=1
)
X_train, X_val = train_test_split(X_train, test_size=0.25, random_state=1)
len(X_train), len(X_val), len(X_test)
# Out:
# (88, 30, 30)

# %% [markdown]
# We now need to retrieve every file and associated scores corresponding to our participants

# %%
def extract_sub(bids_name):
    # sub is the first 10 characters of the bids name
    return bids_name[:10]


def extract_num(bids_name):
    return bids_name[4:10]


scores["participant_id"] = scores["bids_name"].apply(extract_sub)
scores["participant_num"] = scores["bids_name"].apply(extract_num)

scores["data"] = (
    "MRIQC/sub-MR-ART-"
    + scores["participant_num"]
    + "/"
    + scores["bids_name"]
    + "/mri/reg_extracted_orig_nu.nii.gz"
)
scores["label"] = scores["score"] - 1
scores.head()
# Out:
#                         bids_name  score participant_id participant_num  \
# 0     sub-000103_acq-standard_T1w      1     sub-000103          000103
# 1  sub-000103_acq-headmotion1_T1w      2     sub-000103          000103
# 2  sub-000103_acq-headmotion2_T1w      3     sub-000103          000103
# 3     sub-000148_acq-standard_T1w      1     sub-000148          000148
# 4  sub-000148_acq-headmotion1_T1w      3     sub-000148          000148
#
#                                                 data  label
# 0  MRIQC/sub-MR-ART-000103/sub-000103_acq-standar...      0
# 1  MRIQC/sub-MR-ART-000103/sub-000103_acq-headmot...      1
# 2  MRIQC/sub-MR-ART-000103/sub-000103_acq-headmot...      2
# 3  MRIQC/sub-MR-ART-000148/sub-000148_acq-standar...      0
# 4  MRIQC/sub-MR-ART-000148/sub-000148_acq-headmot...      2

# %%
train_files = scores.loc[scores["participant_id"].isin(X_train), ["data", "label"]]
val_files = scores.loc[scores["participant_id"].isin(X_val), ["data", "label"]]
test_files = scores.loc[scores["participant_id"].isin(X_test), ["data", "label"]]
len(train_files), len(val_files), len(test_files)
# Out:
# (258, 89, 89)

# %%
train_files.to_csv("train.csv")
val_files.to_csv("val.csv")
test_files.to_csv("test.csv")

# %%
train_files.to_dict("records")
# Out:
# [{'data': 'MRIQC/sub-MR-ART-000159/sub-000159_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-000159/sub-000159_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-000159/sub-000159_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-000175/sub-000175_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-000175/sub-000175_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 1},
#  {'data': 'MRIQC/sub-MR-ART-000175/sub-000175_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-009673/sub-009673_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-009673/sub-009673_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 1},
#  {'data': 'MRIQC/sub-MR-ART-009673/sub-009673_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-012322/sub-012322_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-012322/sub-012322_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-012322/sub-012322_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-016504/sub-016504_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 1},
#  {'data': 'MRIQC/sub-MR-ART-016504/sub-016504_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-016504/sub-016504_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-105822/sub-105822_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-105822/sub-105822_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-108142/sub-108142_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-108142/sub-108142_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-108142/sub-108142_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-118003/sub-118003_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-118003/sub-118003_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-118003/sub-118003_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-125171/sub-125171_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-125171/sub-125171_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-125171/sub-125171_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-127867/sub-127867_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-127867/sub-127867_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 1},
#  {'data': 'MRIQC/sub-MR-ART-127867/sub-127867_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 1},
#  {'data': 'MRIQC/sub-MR-ART-136038/sub-136038_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-136038/sub-136038_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-143104/sub-143104_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-143104/sub-143104_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-143104/sub-143104_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-149050/sub-149050_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-149050/sub-149050_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-149050/sub-149050_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-152686/sub-152686_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-152686/sub-152686_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-152686/sub-152686_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 1},
#  {'data': 'MRIQC/sub-MR-ART-169618/sub-169618_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-169618/sub-169618_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-169618/sub-169618_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-185823/sub-185823_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-185823/sub-185823_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-196711/sub-196711_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-196711/sub-196711_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 1},
#  {'data': 'MRIQC/sub-MR-ART-196711/sub-196711_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-217720/sub-217720_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-217720/sub-217720_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 1},
#  {'data': 'MRIQC/sub-MR-ART-217720/sub-217720_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 1},
#  {'data': 'MRIQC/sub-MR-ART-219843/sub-219843_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-219843/sub-219843_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 1},
#  {'data': 'MRIQC/sub-MR-ART-219843/sub-219843_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-228373/sub-228373_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-228373/sub-228373_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-228373/sub-228373_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-253493/sub-253493_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-253493/sub-253493_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 1},
#  {'data': 'MRIQC/sub-MR-ART-253493/sub-253493_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-257563/sub-257563_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-257563/sub-257563_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 1},
#  {'data': 'MRIQC/sub-MR-ART-257563/sub-257563_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-261051/sub-261051_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 1},
#  {'data': 'MRIQC/sub-MR-ART-261051/sub-261051_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-261051/sub-261051_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-275147/sub-275147_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 1},
#  {'data': 'MRIQC/sub-MR-ART-275147/sub-275147_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-275147/sub-275147_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-275211/sub-275211_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-275211/sub-275211_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-275211/sub-275211_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-278729/sub-278729_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-278729/sub-278729_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 1},
#  {'data': 'MRIQC/sub-MR-ART-278729/sub-278729_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-282628/sub-282628_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-282628/sub-282628_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-282628/sub-282628_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-292213/sub-292213_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 1},
#  {'data': 'MRIQC/sub-MR-ART-292213/sub-292213_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 1},
#  {'data': 'MRIQC/sub-MR-ART-292213/sub-292213_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-335448/sub-335448_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-335448/sub-335448_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-335448/sub-335448_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-337488/sub-337488_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-337488/sub-337488_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 1},
#  {'data': 'MRIQC/sub-MR-ART-337488/sub-337488_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 1},
#  {'data': 'MRIQC/sub-MR-ART-402511/sub-402511_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-402511/sub-402511_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-402511/sub-402511_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-407309/sub-407309_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-407309/sub-407309_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 1},
#  {'data': 'MRIQC/sub-MR-ART-407309/sub-407309_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-409228/sub-409228_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-409228/sub-409228_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-409228/sub-409228_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-436999/sub-436999_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-436999/sub-436999_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-436999/sub-436999_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-441269/sub-441269_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 1},
#  {'data': 'MRIQC/sub-MR-ART-441269/sub-441269_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 1},
#  {'data': 'MRIQC/sub-MR-ART-441269/sub-441269_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 1},
#  {'data': 'MRIQC/sub-MR-ART-460834/sub-460834_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-460834/sub-460834_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 1},
#  {'data': 'MRIQC/sub-MR-ART-460834/sub-460834_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-502250/sub-502250_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-502250/sub-502250_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-502250/sub-502250_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-517724/sub-517724_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-517724/sub-517724_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 1},
#  {'data': 'MRIQC/sub-MR-ART-517724/sub-517724_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-549056/sub-549056_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 1},
#  {'data': 'MRIQC/sub-MR-ART-549056/sub-549056_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-549056/sub-549056_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-561646/sub-561646_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-561646/sub-561646_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 1},
#  {'data': 'MRIQC/sub-MR-ART-561646/sub-561646_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-567742/sub-567742_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-567742/sub-567742_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-567742/sub-567742_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-570379/sub-570379_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-570379/sub-570379_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-570379/sub-570379_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-581638/sub-581638_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-581638/sub-581638_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 1},
#  {'data': 'MRIQC/sub-MR-ART-581638/sub-581638_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-584264/sub-584264_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 1},
#  {'data': 'MRIQC/sub-MR-ART-584264/sub-584264_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-584264/sub-584264_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-597083/sub-597083_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 1},
#  {'data': 'MRIQC/sub-MR-ART-597083/sub-597083_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-597083/sub-597083_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-598630/sub-598630_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 1},
#  {'data': 'MRIQC/sub-MR-ART-598630/sub-598630_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-599619/sub-599619_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-599619/sub-599619_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 1},
#  {'data': 'MRIQC/sub-MR-ART-599619/sub-599619_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 1},
#  {'data': 'MRIQC/sub-MR-ART-607339/sub-607339_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 1},
#  {'data': 'MRIQC/sub-MR-ART-607339/sub-607339_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 1},
#  {'data': 'MRIQC/sub-MR-ART-607339/sub-607339_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-611047/sub-611047_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-611047/sub-611047_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-611047/sub-611047_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-613957/sub-613957_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-613957/sub-613957_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-630780/sub-630780_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-630780/sub-630780_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-630780/sub-630780_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-645865/sub-645865_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-645865/sub-645865_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-645865/sub-645865_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-652881/sub-652881_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-652881/sub-652881_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 1},
#  {'data': 'MRIQC/sub-MR-ART-652881/sub-652881_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-672229/sub-672229_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-672229/sub-672229_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-672229/sub-672229_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-687508/sub-687508_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-687508/sub-687508_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-687508/sub-687508_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-691641/sub-691641_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-691641/sub-691641_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-691641/sub-691641_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-691777/sub-691777_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-691777/sub-691777_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 1},
#  {'data': 'MRIQC/sub-MR-ART-691777/sub-691777_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-694330/sub-694330_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-694330/sub-694330_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 1},
#  {'data': 'MRIQC/sub-MR-ART-714347/sub-714347_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-714347/sub-714347_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-714347/sub-714347_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-723372/sub-723372_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-723372/sub-723372_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-723372/sub-723372_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-754006/sub-754006_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-754006/sub-754006_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 1},
#  {'data': 'MRIQC/sub-MR-ART-754006/sub-754006_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-754183/sub-754183_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-754183/sub-754183_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-754183/sub-754183_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-757271/sub-757271_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 1},
#  {'data': 'MRIQC/sub-MR-ART-757271/sub-757271_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-757271/sub-757271_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-772389/sub-772389_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-772389/sub-772389_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-772389/sub-772389_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-778481/sub-778481_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-778481/sub-778481_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-778481/sub-778481_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-788339/sub-788339_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-788339/sub-788339_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-788339/sub-788339_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-791907/sub-791907_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-791907/sub-791907_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 1},
#  {'data': 'MRIQC/sub-MR-ART-791907/sub-791907_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 1},
#  {'data': 'MRIQC/sub-MR-ART-802945/sub-802945_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-802945/sub-802945_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-802945/sub-802945_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 1},
#  {'data': 'MRIQC/sub-MR-ART-809320/sub-809320_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-809320/sub-809320_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-809320/sub-809320_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-811563/sub-811563_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 1},
#  {'data': 'MRIQC/sub-MR-ART-811563/sub-811563_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-811563/sub-811563_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 1},
#  {'data': 'MRIQC/sub-MR-ART-830976/sub-830976_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-830976/sub-830976_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-830976/sub-830976_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-848092/sub-848092_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-848092/sub-848092_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-848092/sub-848092_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-865293/sub-865293_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-865293/sub-865293_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 1},
#  {'data': 'MRIQC/sub-MR-ART-865293/sub-865293_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 1},
#  {'data': 'MRIQC/sub-MR-ART-886764/sub-886764_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-886764/sub-886764_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 1},
#  {'data': 'MRIQC/sub-MR-ART-886764/sub-886764_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-890465/sub-890465_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-890465/sub-890465_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-890465/sub-890465_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-914102/sub-914102_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-914102/sub-914102_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-914102/sub-914102_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-923660/sub-923660_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-923660/sub-923660_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-923660/sub-923660_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-926536/sub-926536_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-926536/sub-926536_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-926536/sub-926536_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-927452/sub-927452_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 1},
#  {'data': 'MRIQC/sub-MR-ART-927452/sub-927452_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 1},
#  {'data': 'MRIQC/sub-MR-ART-927452/sub-927452_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 1},
#  {'data': 'MRIQC/sub-MR-ART-938344/sub-938344_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-938344/sub-938344_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 1},
#  {'data': 'MRIQC/sub-MR-ART-938344/sub-938344_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-945122/sub-945122_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-945122/sub-945122_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 1},
#  {'data': 'MRIQC/sub-MR-ART-945122/sub-945122_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-945652/sub-945652_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-945652/sub-945652_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-945652/sub-945652_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-946200/sub-946200_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-946200/sub-946200_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-946200/sub-946200_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-987325/sub-987325_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-987325/sub-987325_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-987325/sub-987325_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-988484/sub-988484_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-988484/sub-988484_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 1},
#  {'data': 'MRIQC/sub-MR-ART-988484/sub-988484_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-988653/sub-988653_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-988653/sub-988653_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 1},
#  {'data': 'MRIQC/sub-MR-ART-988653/sub-988653_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 1},
#  {'data': 'MRIQC/sub-MR-ART-992121/sub-992121_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-992121/sub-992121_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 1},
#  {'data': 'MRIQC/sub-MR-ART-992121/sub-992121_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 1},
#  {'data': 'MRIQC/sub-MR-ART-992238/sub-992238_acq-standard_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 0},
#  {'data': 'MRIQC/sub-MR-ART-992238/sub-992238_acq-headmotion1_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2},
#  {'data': 'MRIQC/sub-MR-ART-992238/sub-992238_acq-headmotion2_T1w/mri/reg_extracted_orig_nu.nii.gz',
#   'label': 2}]

# %% [markdown]
# # Get data for HCP dataset

# %%
participant = pd.read_csv("mriqc.csv", index_col=0)
participant = participant.drop(columns="index")
participant.head()
# Out:
#                    bids_name  qc_issue  score dataset
# 0  sub-BI02450/ses-202306231      True    2.0  AMPSCZ
# 1  sub-BI02450/ses-202304111     False    3.0  AMPSCZ
# 2  sub-BI05529/ses-202306051     False    4.0  AMPSCZ
# 3  sub-BI05652/ses-202304171     False    3.0  AMPSCZ
# 4  sub-BI05874/ses-202305181     False    3.0  AMPSCZ

# %%
hcp = participant[participant.dataset == "HCP-YA-1200"]
hcp.head()
# Out:
#      bids_name  qc_issue  score      dataset
# 1197    100206     False   -1.0  HCP-YA-1200
# 1198    100307     False   -1.0  HCP-YA-1200
# 1199    100408     False   -1.0  HCP-YA-1200
# 1200    100610     False   -1.0  HCP-YA-1200
# 1201    101006     False   -1.0  HCP-YA-1200

# %%
hcp["data"] = (
    "MRIQC/sub-HCP-YA-1200-"
    + hcp["bids_name"]
    + "/"
    + hcp["bids_name"]
    + "_3T_T1w_MPR1/mri/reg_extracted_orig_nu.nii.gz"
)
hcp.head()
# Out:
# /tmp/ipykernel_120524/3021928671.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hcp["data"] = (
#      bids_name  qc_issue  score      dataset  \
# 1197    100206     False   -1.0  HCP-YA-1200
# 1198    100307     False   -1.0  HCP-YA-1200
# 1199    100408     False   -1.0  HCP-YA-1200
# 1200    100610     False   -1.0  HCP-YA-1200
# 1201    101006     False   -1.0  HCP-YA-1200
#
#                                                    data
# 1197  MRIQC/sub-HCP-YA-1200-100206/100206_3T_T1w_MPR...
# 1198  MRIQC/sub-HCP-YA-1200-100307/100307_3T_T1w_MPR...
# 1199  MRIQC/sub-HCP-YA-1200-100408/100408_3T_T1w_MPR...
# 1200  MRIQC/sub-HCP-YA-1200-100610/100610_3T_T1w_MPR...
# 1201  MRIQC/sub-HCP-YA-1200-101006/101006_3T_T1w_MPR...

# %%
hcp[["data"]].to_csv("hcp.csv")

# %% [markdown]
# ## Converting Old MRIQC split to new pipeline

# %%
import re

# %%
train = pd.read_csv("../src/dataset/train.csv", index_col=0)
test = pd.read_csv("../src/dataset/test.csv", index_col=0)
val = pd.read_csv("../src/dataset/val.csv", index_col=0)

train.head()
# Out:
#                                                  data  label
# 9   MRIQC/sub-MR-ART-000159/sub-000159_acq-standar...      0
# 10  MRIQC/sub-MR-ART-000159/sub-000159_acq-headmot...      2
# 11  MRIQC/sub-MR-ART-000159/sub-000159_acq-headmot...      2
# 12  MRIQC/sub-MR-ART-000175/sub-000175_acq-standar...      0
# 13  MRIQC/sub-MR-ART-000175/sub-000175_acq-headmot...      1

# %%
def convert_old_to_new(old_path):
    old_path = old_path.replace("MRIQC/sub-MR-ART-", "MRART-Preproc/subjects/sub-")
    ses = ""
    sub = re.search("\/(sub-[^_\/]*)_acq", old_path)
    end = "space-MNI152NLin2009cSym_desc-Crop_res-1x1x1_T1w.nii.gz"
    if "standard" in old_path:
        ses = "ses-standard"
    elif "headmotion1" in old_path:
        ses = "ses-headmotion1"
    elif "headmotion2" in old_path:
        ses = "ses-headmotion2"

    keep = old_path[: old_path.find(sub.group(1)) + len(sub.group(1))]
    return f"{keep}/{ses}/t1_linear/{sub.group(1)}_{ses}_{end}"

# %%
for ds in (train, val, test):
    ds["data"] = ds["data"].apply(convert_old_to_new)
train.head()
# Out:
#                                                  data  label
# 9   MRART-Preproc/subjects/sub-000159/ses-standard...      0
# 10  MRART-Preproc/subjects/sub-000159/ses-headmoti...      2
# 11  MRART-Preproc/subjects/sub-000159/ses-headmoti...      2
# 12  MRART-Preproc/subjects/sub-000175/ses-standard...      0
# 13  MRART-Preproc/subjects/sub-000175/ses-headmoti...      1

# %%
train.to_csv("../src/dataset/train_preproc.csv")
test.to_csv("../src/dataset/test_preproc.csv")
val.to_csv("../src/dataset/val_preproc.csv")
