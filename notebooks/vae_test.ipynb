# %%
# %load_ext autoreload
# %autoreload 2
import torch
from torchinfo import summary
import sys

sys.path.append("..")
from src.network.sfcn_net import SFCNModel
from src.network.vit_net import ViTModel
from src.network.seres_net import SEResModel
from src.network.cnn_net import CNNModel
imshape = [1, 160, 192, 160]

# %%
net = SFCNModel(imshape, num_classes=3, dropout_rate=0.6).cuda()
summary(
    net,
    (1, 1, 160, 192, 160),
    device="cuda",
    # col_names=("input_size", "output_size", "num_params", "mult_adds"),
)
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# SFCNModel                                     [1, 3]                    --
# ├─SFCNEncoder: 1-1                            [1, 64, 5, 6, 5]          --
# │    └─Sequential: 2-1                        [1, 64, 5, 6, 5]          --
# │    │    └─SFCNBlock: 3-1                    [1, 32, 80, 96, 80]       960
# │    │    └─SFCNBlock: 3-2                    [1, 64, 40, 48, 40]       55,488
# │    │    └─SFCNBlock: 3-3                    [1, 128, 20, 24, 20]      221,568
# │    │    └─SFCNBlock: 3-4                    [1, 256, 10, 12, 10]      885,504
# │    │    └─SFCNBlock: 3-5                    [1, 256, 5, 6, 5]         1,770,240
# │    │    └─SFCNBlock: 3-6                    [1, 64, 5, 6, 5]          16,576
# ├─SFCNClassifier: 1-2                         [1, 3]                    --
# │    └─Identity: 2-2                          [1, 64, 5, 6, 5]          --
# │    └─SFCNHeadBlock: 2-3                     [1, 3]                    --
# │    │    └─AvgPool3d: 3-7                    [1, 64, 1, 1, 1]          --
# │    │    └─Dropout: 3-8                      [1, 64, 1, 1, 1]          --
# │    │    └─Conv3d: 3-9                       [1, 3, 1, 1, 1]           195
# │    │    └─Flatten: 3-10                     [1, 3]                    --
# ===============================================================================================
# Total params: 2,950,531
# Trainable params: 2,950,531
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 66.04
# ===============================================================================================
# Input size (MB): 19.66
# Forward/backward pass size (MB): 3347.40
# Params size (MB): 11.80
# Estimated Total Size (MB): 3378.87
# ===============================================================================================
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
net = ViTModel(imshape, num_classes=3, dropout_rate=0.6).cuda()
summary(
    net,
    (1, 1, 160, 192, 160),
    device="cuda",
    # col_names=("input_size", "output_size", "num_params", "mult_adds"),
)
# Out:
# ====================================================================================================
# Layer (type:depth-idx)                             Output Shape              Param #
# ====================================================================================================
# ViTModel                                           [1, 3]                    --
# ├─ViTEncoder: 1-1                                  [1, 768]                  --
# │    └─ViT: 2-1                                    [1, 1201, 768]            768
# │    │    └─PatchEmbeddingBlock: 3-1               [1, 1200, 768]            4,068,096
# │    │    └─ModuleList: 3-2                        --                        70,855,680
# │    │    └─LayerNorm: 3-3                         [1, 1201, 768]            1,536
# ├─ViTClassifier: 1-2                               [1, 3]                    --
# │    └─Sequential: 2-2                             [1, 768]                  --
# │    │    └─Flatten: 3-4                           [1, 768]                  --
# │    │    └─Dropout: 3-5                           [1, 768]                  --
# │    └─Linear: 2-3                                 [1, 3]                    2,307
# ====================================================================================================
# Total params: 74,928,387
# Trainable params: 74,928,387
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 3.85
# ====================================================================================================
# Input size (MB): 19.66
# Forward/backward pass size (MB): 826.44
# Params size (MB): 296.02
# Estimated Total Size (MB): 1142.12
# ====================================================================================================
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
net = SEResModel(imshape, num_classes=3, dropout_rate=0.6).cuda()
summary(
    net,
    (1, 1, 160, 192, 160),
    device="cuda",
    # col_names=("input_size", "output_size", "num_params", "mult_adds"),
)
# Out:
# =========================================================================================================
# Layer (type:depth-idx)                                  Output Shape              Param #
# =========================================================================================================
# SEResModel                                              [1, 3]                    --
# ├─SEResEncoder: 1-1                                     [1, 128, 5, 6, 5]         --
# │    └─Sequential: 2-1                                  [1, 128, 5, 6, 5]         --
# │    │    └─SEResModule: 3-1                            [1, 8, 80, 96, 80]        2,084
# │    │    └─SEResModule: 3-2                            [1, 16, 40, 48, 40]       10,888
# │    │    └─SEResModule: 3-3                            [1, 32, 20, 24, 20]       43,280
# │    │    └─SEResModule: 3-4                            [1, 64, 10, 12, 10]       172,576
# │    │    └─SEResModule: 3-5                            [1, 128, 5, 6, 5]         689,216
# ├─SEResClassifier: 1-2                                  [1, 3]                    --
# │    └─Sequential: 2-2                                  [1, 256]                  --
# │    │    └─Dropout: 3-6                                [1, 128, 5, 6, 5]         --
# │    │    └─Flatten: 3-7                                [1, 19200]                --
# │    │    └─Linear: 3-8                                 [1, 256]                  4,915,456
# │    │    └─ReLU: 3-9                                   [1, 256]                  --
# │    └─Linear: 2-3                                      [1, 3]                    771
# =========================================================================================================
# Total params: 5,834,271
# Trainable params: 5,834,271
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 21.85
# =========================================================================================================
# Input size (MB): 19.66
# Forward/backward pass size (MB): 2095.11
# Params size (MB): 23.34
# Estimated Total Size (MB): 2138.11
# =========================================================================================================

# %%
net = CNNModel(imshape, num_classes=3, dropout_rate=0.6).cuda()
summary(
    net,
    (1, 1, 160, 192, 160),
    device="cuda",
    # col_names=("input_size", "output_size", "num_params", "mult_adds"),
)
# Out:
# ====================================================================================================
# Layer (type:depth-idx)                             Output Shape              Param #
# ====================================================================================================
# CNNModel                                           [1, 3]                    --
# ├─CNNEncoder: 1-1                                  [1, 512, 5, 6, 5]         --
# │    └─Sequential: 2-1                             [1, 512, 5, 6, 5]         --
# │    │    └─ConvModule: 3-1                        [1, 32, 80, 96, 80]       28,704
# │    │    └─ConvModule: 3-2                        [1, 64, 40, 48, 40]       166,272
# │    │    └─ConvModule: 3-3                        [1, 128, 20, 24, 20]      664,320
# │    │    └─ConvModule: 3-4                        [1, 256, 10, 12, 10]      2,655,744
# │    │    └─ConvModule: 3-5                        [1, 512, 5, 6, 5]         10,619,904
# ├─CNNClassifier: 1-2                               [1, 3]                    --
# │    └─Sequential: 2-2                             [1, 76800]                --
# │    │    └─Flatten: 3-6                           [1, 76800]                --
# │    │    └─Dropout: 3-7                           [1, 76800]                --
# │    └─Linear: 2-3                                 [1, 3]                    230,403
# ====================================================================================================
# Total params: 14,365,347
# Trainable params: 14,365,347
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 41.46
# ====================================================================================================
# Input size (MB): 19.66
# Forward/backward pass size (MB): 838.04
# Params size (MB): 57.46
# Estimated Total Size (MB): 915.16
# ====================================================================================================
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
net = SEResModel(imshape).to("cuda")
summary(
    net,
    (1, 160, 192, 160),
    device="cuda",
    col_names=("input_size", "output_size", "num_params", "mult_adds"),
)
# Out:
# 19200
# =================================================================================================================================================
# Layer (type:depth-idx)                        Input Shape               Output Shape              Param #                   Mult-Adds
# =================================================================================================================================================
# ├─Sequential: 1-1                             [-1, 1, 160, 192, 160]    [-1, 128, 5, 6, 5]        --                        --
# |    └─SEResModule: 2-1                       [-1, 1, 160, 192, 160]    [-1, 8, 80, 96, 80]       --                        --
# |    |    └─Sequential: 3-1                   [-1, 1, 160, 192, 160]    [-1, 8, 160, 192, 160]    2,068                     2,024
# |    |    └─Conv3d: 3-2                       [-1, 1, 160, 192, 160]    [-1, 8, 160, 192, 160]    16                        39,321,600
# |    |    └─Sequential: 3-3                   [-1, 8, 160, 192, 160]    [-1, 8, 80, 96, 80]       --                        --
# |    └─SEResModule: 2-2                       [-1, 8, 80, 96, 80]       [-1, 16, 40, 48, 40]      --                        --
# |    |    └─Sequential: 3-4                   [-1, 8, 80, 96, 80]       [-1, 16, 80, 96, 80]      10,744                    10,656
# |    |    └─Conv3d: 3-5                       [-1, 8, 80, 96, 80]       [-1, 16, 80, 96, 80]      144                       78,643,200
# |    |    └─Sequential: 3-6                   [-1, 16, 80, 96, 80]      [-1, 16, 40, 48, 40]      --                        --
# |    └─SEResModule: 2-3                       [-1, 16, 40, 48, 40]      [-1, 32, 20, 24, 20]      --                        --
# |    |    └─Sequential: 3-7                   [-1, 16, 40, 48, 40]      [-1, 32, 40, 48, 40]      42,736                    42,560
# |    |    └─Conv3d: 3-8                       [-1, 16, 40, 48, 40]      [-1, 32, 40, 48, 40]      544                       39,321,600
# |    |    └─Sequential: 3-9                   [-1, 32, 40, 48, 40]      [-1, 32, 20, 24, 20]      --                        --
# |    └─SEResModule: 2-4                       [-1, 32, 20, 24, 20]      [-1, 64, 10, 12, 10]      --                        --
# |    |    └─Sequential: 3-10                  [-1, 32, 20, 24, 20]      [-1, 64, 20, 24, 20]      170,464                   170,112
# |    |    └─Conv3d: 3-11                      [-1, 32, 20, 24, 20]      [-1, 64, 20, 24, 20]      2,112                     19,660,800
# |    |    └─Sequential: 3-12                  [-1, 64, 20, 24, 20]      [-1, 64, 10, 12, 10]      --                        --
# |    └─SEResModule: 2-5                       [-1, 64, 10, 12, 10]      [-1, 128, 5, 6, 5]        --                        --
# |    |    └─Sequential: 3-13                  [-1, 64, 10, 12, 10]      [-1, 128, 10, 12, 10]     680,896                   680,192
# |    |    └─Conv3d: 3-14                      [-1, 64, 10, 12, 10]      [-1, 128, 10, 12, 10]     8,320                     9,830,400
# |    |    └─Sequential: 3-15                  [-1, 128, 10, 12, 10]     [-1, 128, 5, 6, 5]        --                        --
# ├─Sequential: 1-2                             [-1, 19200]               [-1, 256]                 --                        --
# |    └─Flatten: 2-6                           [-1, 19200]               [-1, 19200]               --                        --
# |    └─Linear: 2-7                            [-1, 19200]               [-1, 256]                 4,915,456                 4,915,200
# |    └─ReLU: 2-8                              [-1, 256]                 [-1, 256]                 --                        --
# |    └─Dropout: 2-9                           [-1, 256]                 [-1, 256]                 --                        --
# ├─Sequential: 1-3                             [-1, 256]                 [-1]                      --                        --
# |    └─Linear: 2-10                           [-1, 256]                 [-1, 1]                   257                       256
# |    └─Flatten: 2-11                          [-1, 1]                   [-1]                      --                        --
# =================================================================================================================================================
# Total params: 5,833,757
# Trainable params: 5,833,757
# Non-trainable params: 0
# Total mult-adds (G): 21.70
# =================================================================================================================================================
# Input size (MB): 18.75
# Forward/backward pass size (MB): 1998.05
# Params size (MB): 22.25
# Estimated Total Size (MB): 2039.05
# =================================================================================================================================================
# =================================================================================================================================================
# Layer (type:depth-idx)                        Input Shape               Output Shape              Param #                   Mult-Adds
# =================================================================================================================================================
# ├─Sequential: 1-1                             [-1, 1, 160, 192, 160]    [-1, 128, 5, 6, 5]        --                        --
# |    └─SEResModule: 2-1                       [-1, 1, 160, 192, 160]    [-1, 8, 80, 96, 80]       --                        --
# |    |    └─Sequential: 3-1                   [-1, 1, 160, 192, 160]    [-1, 8, 160, 192, 160]    2,068                     2,024
# |    |    └─Conv3d: 3-2                       [-1, 1, 160, 192, 160]    [-1, 8, 160, 192, 160]    16                        39,321,600
# |    |    └─Sequential: 3-3                   [-1, 8, 160, 192, 160]    [-1, 8, 80, 96, 80]       --                        --
# |    └─SEResModule: 2-2                       [-1, 8, 80, 96, 80]       [-1, 16, 40, 48, 40]      --                        --
# |    |    └─Sequential: 3-4                   [-1, 8, 80, 96, 80]       [-1, 16, 80, 96, 80]      10,744                    10,656
# |    |    └─Conv3d: 3-5                       [-1, 8, 80, 96, 80]       [-1, 16, 80, 96, 80]      144                       78,643,200
# |    |    └─Sequential: 3-6                   [-1, 16, 80, 96, 80]      [-1, 16, 40, 48, 40]      --                        --
# |    └─SEResModule: 2-3                       [-1, 16, 40, 48, 40]      [-1, 32, 20, 24, 20]      --                        --
# |    |    └─Sequential: 3-7                   [-1, 16, 40, 48, 40]      [-1, 32, 40, 48, 40]      42,736                    42,560
# |    |    └─Conv3d: 3-8                       [-1, 16, 40, 48, 40]      [-1, 32, 40, 48, 40]      544                       39,321,600
# |    |    └─Sequential: 3-9                   [-1, 32, 40, 48, 40]      [-1, 32, 20, 24, 20]      --                        --
# |    └─SEResModule: 2-4                       [-1, 32, 20, 24, 20]      [-1, 64, 10, 12, 10]      --                        --
# |    |    └─Sequential: 3-10                  [-1, 32, 20, 24, 20]      [-1, 64, 20, 24, 20]      170,464                   170,112
# |    |    └─Conv3d: 3-11                      [-1, 32, 20, 24, 20]      [-1, 64, 20, 24, 20]      2,112                     19,660,800
# |    |    └─Sequential: 3-12                  [-1, 64, 20, 24, 20]      [-1, 64, 10, 12, 10]      --                        --
# |    └─SEResModule: 2-5                       [-1, 64, 10, 12, 10]      [-1, 128, 5, 6, 5]        --                        --
# |    |    └─Sequential: 3-13                  [-1, 64, 10, 12, 10]      [-1, 128, 10, 12, 10]     680,896                   680,192
# |    |    └─Conv3d: 3-14                      [-1, 64, 10, 12, 10]      [-1, 128, 10, 12, 10]     8,320                     9,830,400
# |    |    └─Sequential: 3-15                  [-1, 128, 10, 12, 10]     [-1, 128, 5, 6, 5]        --                        --
# ├─Sequential: 1-2                             [-1, 19200]               [-1, 256]                 --                        --
# |    └─Flatten: 2-6                           [-1, 19200]               [-1, 19200]               --                        --
# |    └─Linear: 2-7                            [-1, 19200]               [-1, 256]                 4,915,456                 4,915,200
# |    └─ReLU: 2-8                              [-1, 256]                 [-1, 256]                 --                        --
# |    └─Dropout: 2-9                           [-1, 256]                 [-1, 256]                 --                        --
# ├─Sequential: 1-3                             [-1, 256]                 [-1]                      --                        --
# |    └─Linear: 2-10                           [-1, 256]                 [-1, 1]                   257                       256
# |    └─Flatten: 2-11                          [-1, 1]                   [-1]                      --                        --
# =================================================================================================================================================
# Total params: 5,833,757
# Trainable params: 5,833,757
# Non-trainable params: 0
# Total mult-adds (G): 21.70
# =================================================================================================================================================
# Input size (MB): 18.75
# Forward/backward pass size (MB): 1998.05
# Params size (MB): 22.25
# Estimated Total Size (MB): 2039.05
# =================================================================================================================================================

# %%
net = ResNetModel(imshape).to("cuda")
summary(
    net,
    (1, 160, 192, 160),
    device="cuda",
    col_names=("input_size", "output_size", "num_params", "mult_adds"),
)
# Out:
# 19200
# ============================================================================================================================================
# Layer (type:depth-idx)                   Input Shape               Output Shape              Param #                   Mult-Adds
# ============================================================================================================================================
# ├─Sequential: 1-1                        [-1, 1, 160, 192, 160]    [-1, 128, 5, 6, 5]        --                        --
# |    └─ResConvModule: 2-1                [-1, 1, 160, 192, 160]    [-1, 8, 80, 96, 80]       --                        --
# |    |    └─Sequential: 3-1              [-1, 1, 160, 192, 160]    [-1, 8, 160, 192, 160]    1,992                     1,960
# |    |    └─Conv3d: 3-2                  [-1, 1, 160, 192, 160]    [-1, 8, 160, 192, 160]    16                        39,321,600
# |    |    └─Sequential: 3-3              [-1, 8, 160, 192, 160]    [-1, 8, 80, 96, 80]       --                        --
# |    └─ResConvModule: 2-2                [-1, 8, 80, 96, 80]       [-1, 16, 40, 48, 40]      --                        --
# |    |    └─Sequential: 3-4              [-1, 8, 80, 96, 80]       [-1, 16, 80, 96, 80]      10,464                    10,400
# |    |    └─Conv3d: 3-5                  [-1, 8, 80, 96, 80]       [-1, 16, 80, 96, 80]      144                       78,643,200
# |    |    └─Sequential: 3-6              [-1, 16, 80, 96, 80]      [-1, 16, 40, 48, 40]      --                        --
# |    └─ResConvModule: 2-3                [-1, 16, 40, 48, 40]      [-1, 32, 20, 24, 20]      --                        --
# |    |    └─Sequential: 3-7              [-1, 16, 40, 48, 40]      [-1, 32, 40, 48, 40]      41,664                    41,536
# |    |    └─Conv3d: 3-8                  [-1, 16, 40, 48, 40]      [-1, 32, 40, 48, 40]      544                       39,321,600
# |    |    └─Sequential: 3-9              [-1, 32, 40, 48, 40]      [-1, 32, 20, 24, 20]      --                        --
# |    └─ResConvModule: 2-4                [-1, 32, 20, 24, 20]      [-1, 64, 10, 12, 10]      --                        --
# |    |    └─Sequential: 3-10             [-1, 32, 20, 24, 20]      [-1, 64, 20, 24, 20]      166,272                   166,016
# |    |    └─Conv3d: 3-11                 [-1, 32, 20, 24, 20]      [-1, 64, 20, 24, 20]      2,112                     19,660,800
# |    |    └─Sequential: 3-12             [-1, 64, 20, 24, 20]      [-1, 64, 10, 12, 10]      --                        --
# |    └─ResConvModule: 2-5                [-1, 64, 10, 12, 10]      [-1, 128, 5, 6, 5]        --                        --
# |    |    └─Sequential: 3-13             [-1, 64, 10, 12, 10]      [-1, 128, 10, 12, 10]     664,320                   663,808
# |    |    └─Conv3d: 3-14                 [-1, 64, 10, 12, 10]      [-1, 128, 10, 12, 10]     8,320                     9,830,400
# |    |    └─Sequential: 3-15             [-1, 128, 10, 12, 10]     [-1, 128, 5, 6, 5]        --                        --
# ├─Sequential: 1-2                        [-1, 19200]               [-1, 256]                 --                        --
# |    └─Flatten: 2-6                      [-1, 19200]               [-1, 19200]               --                        --
# |    └─Linear: 2-7                       [-1, 19200]               [-1, 256]                 4,915,456                 4,915,200
# |    └─ReLU: 2-8                         [-1, 256]                 [-1, 256]                 --                        --
# |    └─Dropout: 2-9                      [-1, 256]                 [-1, 256]                 --                        --
# ├─Sequential: 1-3                        [-1, 256]                 [-1]                      --                        --
# |    └─Linear: 2-10                      [-1, 256]                 [-1, 1]                   257                       256
# |    └─Flatten: 2-11                     [-1, 1]                   [-1]                      --                        --
# ============================================================================================================================================
# Total params: 5,811,561
# Trainable params: 5,811,561
# Non-trainable params: 0
# Total mult-adds (G): 21.70
# ============================================================================================================================================
# Input size (MB): 18.75
# Forward/backward pass size (MB): 1998.05
# Params size (MB): 22.17
# Estimated Total Size (MB): 2038.97
# ============================================================================================================================================
# ============================================================================================================================================
# Layer (type:depth-idx)                   Input Shape               Output Shape              Param #                   Mult-Adds
# ============================================================================================================================================
# ├─Sequential: 1-1                        [-1, 1, 160, 192, 160]    [-1, 128, 5, 6, 5]        --                        --
# |    └─ResConvModule: 2-1                [-1, 1, 160, 192, 160]    [-1, 8, 80, 96, 80]       --                        --
# |    |    └─Sequential: 3-1              [-1, 1, 160, 192, 160]    [-1, 8, 160, 192, 160]    1,992                     1,960
# |    |    └─Conv3d: 3-2                  [-1, 1, 160, 192, 160]    [-1, 8, 160, 192, 160]    16                        39,321,600
# |    |    └─Sequential: 3-3              [-1, 8, 160, 192, 160]    [-1, 8, 80, 96, 80]       --                        --
# |    └─ResConvModule: 2-2                [-1, 8, 80, 96, 80]       [-1, 16, 40, 48, 40]      --                        --
# |    |    └─Sequential: 3-4              [-1, 8, 80, 96, 80]       [-1, 16, 80, 96, 80]      10,464                    10,400
# |    |    └─Conv3d: 3-5                  [-1, 8, 80, 96, 80]       [-1, 16, 80, 96, 80]      144                       78,643,200
# |    |    └─Sequential: 3-6              [-1, 16, 80, 96, 80]      [-1, 16, 40, 48, 40]      --                        --
# |    └─ResConvModule: 2-3                [-1, 16, 40, 48, 40]      [-1, 32, 20, 24, 20]      --                        --
# |    |    └─Sequential: 3-7              [-1, 16, 40, 48, 40]      [-1, 32, 40, 48, 40]      41,664                    41,536
# |    |    └─Conv3d: 3-8                  [-1, 16, 40, 48, 40]      [-1, 32, 40, 48, 40]      544                       39,321,600
# |    |    └─Sequential: 3-9              [-1, 32, 40, 48, 40]      [-1, 32, 20, 24, 20]      --                        --
# |    └─ResConvModule: 2-4                [-1, 32, 20, 24, 20]      [-1, 64, 10, 12, 10]      --                        --
# |    |    └─Sequential: 3-10             [-1, 32, 20, 24, 20]      [-1, 64, 20, 24, 20]      166,272                   166,016
# |    |    └─Conv3d: 3-11                 [-1, 32, 20, 24, 20]      [-1, 64, 20, 24, 20]      2,112                     19,660,800
# |    |    └─Sequential: 3-12             [-1, 64, 20, 24, 20]      [-1, 64, 10, 12, 10]      --                        --
# |    └─ResConvModule: 2-5                [-1, 64, 10, 12, 10]      [-1, 128, 5, 6, 5]        --                        --
# |    |    └─Sequential: 3-13             [-1, 64, 10, 12, 10]      [-1, 128, 10, 12, 10]     664,320                   663,808
# |    |    └─Conv3d: 3-14                 [-1, 64, 10, 12, 10]      [-1, 128, 10, 12, 10]     8,320                     9,830,400
# |    |    └─Sequential: 3-15             [-1, 128, 10, 12, 10]     [-1, 128, 5, 6, 5]        --                        --
# ├─Sequential: 1-2                        [-1, 19200]               [-1, 256]                 --                        --
# |    └─Flatten: 2-6                      [-1, 19200]               [-1, 19200]               --                        --
# |    └─Linear: 2-7                       [-1, 19200]               [-1, 256]                 4,915,456                 4,915,200
# |    └─ReLU: 2-8                         [-1, 256]                 [-1, 256]                 --                        --
# |    └─Dropout: 2-9                      [-1, 256]                 [-1, 256]                 --                        --
# ├─Sequential: 1-3                        [-1, 256]                 [-1]                      --                        --
# |    └─Linear: 2-10                      [-1, 256]                 [-1, 1]                   257                       256
# |    └─Flatten: 2-11                     [-1, 1]                   [-1]                      --                        --
# ============================================================================================================================================
# Total params: 5,811,561
# Trainable params: 5,811,561
# Non-trainable params: 0
# Total mult-adds (G): 21.70
# ============================================================================================================================================
# Input size (MB): 18.75
# Forward/backward pass size (MB): 1998.05
# Params size (MB): 22.17
# Estimated Total Size (MB): 2038.97
# ============================================================================================================================================

# %%
net = Conv5_FC3(imshape).to("cuda")
summary(
    net,
    (1, 160, 192, 160),
    device="cuda",
    col_names=("input_size", "output_size", "num_params", "mult_adds"),
)
# Out:
# tensor([[[[[1.8590e+00, 1.9051e+00, 1.0099e+00, 1.1634e+00, 9.9666e-01],
#            [1.8511e+00, 8.6949e-01, 1.0594e+00, 1.3986e+00, 1.0934e+00],
#
#           [[2.1286e+00, 1.1263e+00, 9.7513e-01, 1.3892e+00, 4.5665e-01],
#            [3.0117e+00, 1.0484e+00, 1.3753e+00, 7.1711e-01, 7.8077e-01],
#            [9.9558e-01, 5.2687e-01, 1.7413e+00, 8.3612e-01, 1.1958e+00],
#            [1.6992e+00, 4.4825e-01, 9.2089e-01, 5.8973e-01, 9.7044e-01],
#            [2.1203e+00, 1.3945e+00, 9.1697e-01, 8.2060e-01, 1.1755e+00],
#            [2.1056e+00, 1.1638e+00, 8.9086e-01, 1.2302e+00, 1.3832e+00]],
#
#           [[1.6753e+00, 9.6400e-01, 1.3542e+00, 1.3887e+00, 5.9301e-01],
#            [2.4819e+00, 6.6133e-01, 1.3856e+00, 6.9934e-01, 1.3455e+00],
#            [1.6496e+00, 1.2292e+00, 1.4067e+00, 1.0709e+00, 1.4862e+00],
#            [1.7087e+00, 1.0268e+00, 4.5639e-01, 1.3722e+00, 9.5477e-01],
#            [9.1585e-01, 7.4976e-01, 1.5291e+00, 1.0001e+00, 1.0347e+00],
#            [2.0541e+00, 8.8823e-01, 4.5181e-01, 8.0278e-01, 2.2853e+00]],
#
#           [[2.2781e+00, 1.5689e+00, 1.6619e+00, 2.2451e+00, 1.9128e+00],
#            [1.8528e+00, 1.6005e+00, 1.4046e+00, 1.1066e+00, 1.6508e+00],
#            [1.8550e+00, 1.4851e+00, 2.0452e+00, 1.9138e+00, 1.8218e+00],
#            [1.0892e+00, 1.1792e+00, 1.5022e+00, 1.7761e+00, 1.6452e+00],
#            [1.4715e+00, 1.4319e+00, 1.7185e+00, 1.4503e+00, 1.5094e+00],
#            [1.5957e+00, 8.4290e-01, 9.1288e-01, 1.1721e+00, 2.1757e+00]]]]],
#        grad_fn=<MaxPool3DWithIndicesBackward0>)
# ============================================================================================================================================
# Layer (type:depth-idx)                   Input Shape               Output Shape              Param #                   Mult-Adds
# ============================================================================================================================================
# ├─Sequential: 1-1                        [-1, 1, 160, 192, 160]    [-1, 128, 5, 6, 5]        --                        --
# |    └─ConvBlock: 2-1                    [-1, 1, 160, 192, 160]    [-1, 8, 80, 96, 80]       --                        --
# |    |    └─Conv3d: 3-1                  [-1, 1, 160, 192, 160]    [-1, 8, 160, 192, 160]    224                       1,061,683,200
# |    |    └─BatchNorm3d: 3-2             [-1, 8, 160, 192, 160]    [-1, 8, 160, 192, 160]    16                        8
# |    |    └─ReLU: 3-3                    [-1, 8, 160, 192, 160]    [-1, 8, 160, 192, 160]    --                        --
# |    |    └─MaxPool3d: 3-4               [-1, 8, 160, 192, 160]    [-1, 8, 80, 96, 80]       --                        --
# |    └─ConvBlock: 2-2                    [-1, 8, 80, 96, 80]       [-1, 16, 40, 48, 40]      --                        --
# |    |    └─Conv3d: 3-5                  [-1, 8, 80, 96, 80]       [-1, 16, 80, 96, 80]      3,472                     2,123,366,400
# |    |    └─BatchNorm3d: 3-6             [-1, 16, 80, 96, 80]      [-1, 16, 80, 96, 80]      32                        16
# |    |    └─ReLU: 3-7                    [-1, 16, 80, 96, 80]      [-1, 16, 80, 96, 80]      --                        --
# |    |    └─MaxPool3d: 3-8               [-1, 16, 80, 96, 80]      [-1, 16, 40, 48, 40]      --                        --
# |    └─ConvBlock: 2-3                    [-1, 16, 40, 48, 40]      [-1, 32, 20, 24, 20]      --                        --
# |    |    └─Conv3d: 3-9                  [-1, 16, 40, 48, 40]      [-1, 32, 40, 48, 40]      13,856                    1,061,683,200
# |    |    └─BatchNorm3d: 3-10            [-1, 32, 40, 48, 40]      [-1, 32, 40, 48, 40]      64                        32
# |    |    └─ReLU: 3-11                   [-1, 32, 40, 48, 40]      [-1, 32, 40, 48, 40]      --                        --
# |    |    └─MaxPool3d: 3-12              [-1, 32, 40, 48, 40]      [-1, 32, 20, 24, 20]      --                        --
# |    └─ConvBlock: 2-4                    [-1, 32, 20, 24, 20]      [-1, 64, 10, 12, 10]      --                        --
# |    |    └─Conv3d: 3-13                 [-1, 32, 20, 24, 20]      [-1, 64, 20, 24, 20]      55,360                    530,841,600
# |    |    └─BatchNorm3d: 3-14            [-1, 64, 20, 24, 20]      [-1, 64, 20, 24, 20]      128                       64
# |    |    └─ReLU: 3-15                   [-1, 64, 20, 24, 20]      [-1, 64, 20, 24, 20]      --                        --
# |    |    └─MaxPool3d: 3-16              [-1, 64, 20, 24, 20]      [-1, 64, 10, 12, 10]      --                        --
# |    └─ConvBlock: 2-5                    [-1, 64, 10, 12, 10]      [-1, 128, 5, 6, 5]        --                        --
# |    |    └─Conv3d: 3-17                 [-1, 64, 10, 12, 10]      [-1, 128, 10, 12, 10]     221,312                   265,420,800
# |    |    └─BatchNorm3d: 3-18            [-1, 128, 10, 12, 10]     [-1, 128, 10, 12, 10]     256                       128
# |    |    └─ReLU: 3-19                   [-1, 128, 10, 12, 10]     [-1, 128, 10, 12, 10]     --                        --
# |    |    └─MaxPool3d: 3-20              [-1, 128, 10, 12, 10]     [-1, 128, 5, 6, 5]        --                        --
# ├─Sequential: 1-2                        [-1, 128, 5, 6, 5]        [-1, 50]                  --                        --
# |    └─Flatten: 2-6                      [-1, 128, 5, 6, 5]        [-1, 19200]               --                        --
# |    └─Dropout: 2-7                      [-1, 19200]               [-1, 19200]               --                        --
# |    └─Linear: 2-8                       [-1, 19200]               [-1, 1300]                24,961,300                24,960,000
# |    └─Linear: 2-9                       [-1, 1300]                [-1, 50]                  65,050                    65,000
# ├─Sequential: 1-3                        [-1, 50]                  [-1]                      --                        --
# |    └─Linear: 2-10                      [-1, 50]                  [-1, 1]                   51                        50
# |    └─Flatten: 2-11                     [-1, 1]                   [-1]                      --                        --
# ============================================================================================================================================
# Total params: 25,321,121
# Trainable params: 25,321,121
# Non-trainable params: 0
# Total mult-adds (G): 5.09
# ============================================================================================================================================
# Input size (MB): 18.75
# Forward/backward pass size (MB): 799.23
# Params size (MB): 96.59
# Estimated Total Size (MB): 914.57
# ============================================================================================================================================
# ============================================================================================================================================
# Layer (type:depth-idx)                   Input Shape               Output Shape              Param #                   Mult-Adds
# ============================================================================================================================================
# ├─Sequential: 1-1                        [-1, 1, 160, 192, 160]    [-1, 128, 5, 6, 5]        --                        --
# |    └─ConvBlock: 2-1                    [-1, 1, 160, 192, 160]    [-1, 8, 80, 96, 80]       --                        --
# |    |    └─Conv3d: 3-1                  [-1, 1, 160, 192, 160]    [-1, 8, 160, 192, 160]    224                       1,061,683,200
# |    |    └─BatchNorm3d: 3-2             [-1, 8, 160, 192, 160]    [-1, 8, 160, 192, 160]    16                        8
# |    |    └─ReLU: 3-3                    [-1, 8, 160, 192, 160]    [-1, 8, 160, 192, 160]    --                        --
# |    |    └─MaxPool3d: 3-4               [-1, 8, 160, 192, 160]    [-1, 8, 80, 96, 80]       --                        --
# |    └─ConvBlock: 2-2                    [-1, 8, 80, 96, 80]       [-1, 16, 40, 48, 40]      --                        --
# |    |    └─Conv3d: 3-5                  [-1, 8, 80, 96, 80]       [-1, 16, 80, 96, 80]      3,472                     2,123,366,400
# |    |    └─BatchNorm3d: 3-6             [-1, 16, 80, 96, 80]      [-1, 16, 80, 96, 80]      32                        16
# |    |    └─ReLU: 3-7                    [-1, 16, 80, 96, 80]      [-1, 16, 80, 96, 80]      --                        --
# |    |    └─MaxPool3d: 3-8               [-1, 16, 80, 96, 80]      [-1, 16, 40, 48, 40]      --                        --
# |    └─ConvBlock: 2-3                    [-1, 16, 40, 48, 40]      [-1, 32, 20, 24, 20]      --                        --
# |    |    └─Conv3d: 3-9                  [-1, 16, 40, 48, 40]      [-1, 32, 40, 48, 40]      13,856                    1,061,683,200
# |    |    └─BatchNorm3d: 3-10            [-1, 32, 40, 48, 40]      [-1, 32, 40, 48, 40]      64                        32
# |    |    └─ReLU: 3-11                   [-1, 32, 40, 48, 40]      [-1, 32, 40, 48, 40]      --                        --
# |    |    └─MaxPool3d: 3-12              [-1, 32, 40, 48, 40]      [-1, 32, 20, 24, 20]      --                        --
# |    └─ConvBlock: 2-4                    [-1, 32, 20, 24, 20]      [-1, 64, 10, 12, 10]      --                        --
# |    |    └─Conv3d: 3-13                 [-1, 32, 20, 24, 20]      [-1, 64, 20, 24, 20]      55,360                    530,841,600
# |    |    └─BatchNorm3d: 3-14            [-1, 64, 20, 24, 20]      [-1, 64, 20, 24, 20]      128                       64
# |    |    └─ReLU: 3-15                   [-1, 64, 20, 24, 20]      [-1, 64, 20, 24, 20]      --                        --
# |    |    └─MaxPool3d: 3-16              [-1, 64, 20, 24, 20]      [-1, 64, 10, 12, 10]      --                        --
# |    └─ConvBlock: 2-5                    [-1, 64, 10, 12, 10]      [-1, 128, 5, 6, 5]        --                        --
# |    |    └─Conv3d: 3-17                 [-1, 64, 10, 12, 10]      [-1, 128, 10, 12, 10]     221,312                   265,420,800
# |    |    └─BatchNorm3d: 3-18            [-1, 128, 10, 12, 10]     [-1, 128, 10, 12, 10]     256                       128
# |    |    └─ReLU: 3-19                   [-1, 128, 10, 12, 10]     [-1, 128, 10, 12, 10]     --                        --
# |    |    └─MaxPool3d: 3-20              [-1, 128, 10, 12, 10]     [-1, 128, 5, 6, 5]        --                        --
# ├─Sequential: 1-2                        [-1, 128, 5, 6, 5]        [-1, 50]                  --                        --
# |    └─Flatten: 2-6                      [-1, 128, 5, 6, 5]        [-1, 19200]               --                        --
# |    └─Dropout: 2-7                      [-1, 19200]               [-1, 19200]               --                        --
# |    └─Linear: 2-8                       [-1, 19200]               [-1, 1300]                24,961,300                24,960,000
# |    └─Linear: 2-9                       [-1, 1300]                [-1, 50]                  65,050                    65,000
# ├─Sequential: 1-3                        [-1, 50]                  [-1]                      --                        --
# |    └─Linear: 2-10                      [-1, 50]                  [-1, 1]                   51                        50
# |    └─Flatten: 2-11                     [-1, 1]                   [-1]                      --                        --
# ============================================================================================================================================
# Total params: 25,321,121
# Trainable params: 25,321,121
# Non-trainable params: 0
# Total mult-adds (G): 5.09
# ============================================================================================================================================
# Input size (MB): 18.75
# Forward/backward pass size (MB): 799.23
# Params size (MB): 96.59
# Estimated Total Size (MB): 914.57
# ============================================================================================================================================
